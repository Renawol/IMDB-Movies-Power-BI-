# %% [markdown]
# # IMDB dataset cleaning

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from ydata_profiling import ProfileReport

# %%
path = r'C:\Users\mateo\OneDrive\Escritorio\Ciencia de datos\Proyectos\IMDB\imdb_data.csv'

# %%
data = pd.read_csv(path)

# %%
data.head()
# Out:
#           id    primaryTitle   originalTitle  isAdult  runtimeMinutes  \
# 0  tt0035423  Kate & Leopold  Kate & Leopold        0             118
# 1  tt0065421  The Aristocats  The AristoCats        0              78
# 2  tt0065938  Kelly's Heroes  Kelly's Heroes        0             144
# 3  tt0066026         M*A*S*H         M*A*S*H        0             116
# 4  tt0066206          Patton          Patton        0             172
#
#                        genres  averageRating  numVotes    budget       gross  \
# 0      Comedy,Fantasy,Romance            6.4     87925  48000000  76019048.0
# 1  Adventure,Animation,Comedy            7.1    111758   4000000  35459543.0
# 2        Adventure,Comedy,War            7.6     52628   4000000   5200000.0
# 3            Comedy,Drama,War            7.4     75784   3500000  81600000.0
# 4         Biography,Drama,War            7.9    106476  12000000  61749765.0
#
#         release_date              directors
# ...

# %%
data['id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (3348, 12)

# %%
data.isna().sum() / data.shape[0] * 100
# Out:
# id                0.000000
# primaryTitle      0.000000
# originalTitle     0.000000
# isAdult           0.000000
# runtimeMinutes    0.000000
# genres            0.000000
# averageRating     0.000000
# numVotes          0.000000
# budget            0.000000
# gross             1.523297
# release_date      0.149343
# directors         0.000000
# dtype: float64

# %%
data[data['release_date'].isna()]
# Out:
#              id      primaryTitle     originalTitle  isAdult  runtimeMinutes  \
# 465   tt0107048     Groundhog Day     Groundhog Day        0             101
# 524   tt0110932         Quiz Show         Quiz Show        0             133
# 1190  tt0307453        Shark Tale        Shark Tale        0              90
# 1298  tt0348333        Waiting...        Waiting...        0              94
# 2876  tt2649554  Midnight Special  Midnight Special        0             112
#
#                           genres  averageRating  numVotes    budget  \
# 465         Comedy,Drama,Fantasy            8.0    666512  14600000
# 524      Biography,Drama,History            7.5     72316  31000000
# 1190  Adventure,Animation,Comedy            6.0    194771  75000000
# 1298                      Comedy            6.7    103903   3000000
# 2876        Drama,Mystery,Sci-Fi            6.6     83229  18000000
#
#             gross release_date                                   directors
# ...

# %%
data.loc[465, 'release_date'] = 'February 2, 1993'
data.loc[524, 'release_date'] = 'September 12, 1994'
data.loc[1190, 'release_date'] = 'September 10, 2004'
data.loc[1298, 'release_date'] = 'October 7, 2005'
data.loc[2876, 'release_date'] = 'February 16, 2016'

# %%
data[data['gross'].isna()]
# Out:
#               id                     primaryTitle  \
# 12     tt0067800                       Straw Dogs
# 26     tt0070510                       Paper Moon
# 28     tt0070608                       Robin Hood
# 33     tt0070909                        Westworld
# 50     tt0074156           Assault on Precinct 13
# 53     tt0074812                      Logan's Run
# 80     tt0078935               Cannibal Holocaust
# 426    tt0104684                      Hard Boiled
# 1764   tt0756683               The Man from Earth
# 1866   tt0862856                   Trick 'r Treat
# 1953   tt0993840                 Army of the Dead
# 2033   tt1070874       The Trial of the Chicago 7
# 2072   tt1117385                            Felon
# 2121  tt11671006             The Man from Toronto
# 2128  tt11755740          Texas Chainsaw Massacre
# 2141  tt11866324                             Prey
# 2150  tt11909878                    Hocus Pocus 2
# 2216  tt12361974     Zack Snyder's Justice League
# ...

# %% [markdown]
# 'isAdult' column is dropped because its value is always 0

# %%
data.drop('isAdult', axis = 1, inplace = True)

# %% [markdown]
# rows whose 'gross' column is null are going to be dropped too as they represent just the 1.5% of the data. Besides, we want focus into the visualization part.

# %%
data.dropna()
